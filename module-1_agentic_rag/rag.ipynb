# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI
import os

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
client = OpenAI(
    api_key = os.getenv("GROQ_API_KEY"),
    base_url = "https://api.groq.com/openai/v1"
)

# %%
assistant = RAGBase(
    index = index,
    llm_client = client,
)

# %%
answer = assistant.rag("How do i get a certificate?")
print(answer)
# Out:
# **Getting a Certificate**
#
# To get a certificate after completing the course, you need to follow these steps:
#
# 1. **Finish the course with a "live" cohort**: You can't get a certificate if you follow the course in self-paced mode. You must be part of a live cohort.
# 2. **Pass the Capstone project**: The Capstone project is mandatory for getting a certificate. You need to submit your project and pass the peer-review process.
#
# **Peer-Review Process**
#
# 1. **Peer-review 3 capstones**: After submitting your project, you need to peer-review at least 3 capstones belonging to other students.
# 2. **Peer-review at the time the course is running**: You can only peer-review projects when the course is running. After the form is closed, the peer-review list is compiled, and you won't be able to make any changes.
#
# **Mandatory Information on the Certificate**
#
# To have your official name displayed on the certificate instead of the random name "Lucid Elbakyan", you need to provide your official name in the "**Official name**" field in your course profile before the peer-review process is completed. You can access your course profile by clicking on the "Edit Course Profile" button.
#
# **Leaderboard and Rank**
#
# If you're not on the leaderboard, you can find your entry by following these steps:
#
# 1. Click on the "Jump to your record on the leaderboard" link.
# 2. Find your random name, such as "Lucid Elbakyan", and click on it to see your entry.
# 3. To see which leaderboard you're on, click on the "Edit Course Profile" button and look for your Display name.
#
# Remember, finishing the course with a live cohort, passing the Capstone project, and providing your official name in your course profile are essential for getting a certificate.
